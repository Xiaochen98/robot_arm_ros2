# %%
import cv2 as cv
import threading
import time
import ipywidgets as widgets
from IPython.display import display
from gesture_stacking import Gesture_Stacking
from dofbot_utils.fps import FPS
from dofbot_utils.robot_controller import Robot_Controller
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
robot = Robot_Controller()
robot.move_init_pose()
fps = FPS()

gesture = Gesture_Stacking()
model = 'General'
# Out:
# Error in cpuinfo: prctl(PR_SVE_GET_VL) failed
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
button_layout      = widgets.Layout(width='320px', height='60px', align_self='auto')
output = widgets.Output()

# 退出 exit
exit_button = widgets.Button(description='Exit', button_style='danger', layout=button_layout)

# 图像控件 Image widget
imgbox = widgets.Image(format='jpg', height=480, width=640)
# 垂直布局 Vertical layout
display_box = widgets.VBox([imgbox, exit_button])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1744970187.057100  222495 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
def exit_button_Callback(value):
    global model
    model = 'Exit'
    with output:
        print(model)

exit_button.on_click(exit_button_Callback)

# %%
def camera():
    global model, gesture
    # 打开摄像头 Open camera
    capture = cv.VideoCapture(0, cv.CAP_V4L2)
    capture.set(3, 640)
    capture.set(4, 480)
    # Be executed in loop when the camera is opened normally 
    # 当摄像头正常打开的情况下循环执行
    while capture.isOpened():
        try:
            _, img = capture.read()
            fps.update_fps()
            gesture.process(img)
            if model == 'Exit':
                capture.release()
                del gesture
                break
            fps.show_fps(img)
            imgbox.value = cv.imencode('.jpg', img)[1].tobytes()
            time.sleep(0.002)
        except Exception as e:
            print("program end")
            print(e)
            capture.release()
# Out:
# W0000 00:00:1744970187.075336  222495 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
display(display_box,output)
threading.Thread(target=camera, ).start()
# Out:
# VBox(children=(Image(value=b'', format='jpg', height='480', width='640'), Button(button_style='danger', descri…
# Output()
# W0000 00:00:1744970189.552282  222496 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
